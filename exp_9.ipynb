# %% [markdown]
# <a href="https://colab.research.google.com/github/gunashekar540/dwdm/blob/main/exp_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
data=pd.read_csv('/content/hclustdata.csv')
data.head()
# Out:
#                     Name  Gender  SSC Perc\nentage  inter/Diplo0a perc  \
# 0        ARIGELA AVINASH       0              87.3                65.3
# 1     BALADARI KEERTHANA       1              89.0                92.4
# 2  BAVIRISETTI PRAVALIKA       1              67.0                68.0
# 3         BODDU SAI BABA       0              71.0                70.4
# 4     BONDAPALLISRINIVAS       0              67.0                65.5
#
#    B.Tech perc  Back\nlogs
# 0        40.00          18
# 1        71.45           0
# 2        45.26          13
# 3        36.47          17
# 4        42.52          17

# %%
x=data.drop('Name',axis=1)
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
cluster=AgglomerativeClustering(n_clusters=3,linkage='ward')
cluster.fit(x_scaled)
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
plt.scatter(x_scaled[:,3],x_scaled[:,4],c=cluster.labels_,cmap='viridis')
plt.xlabel('SSC Perc\nentage')
plt.ylabel('inter/Diplo0a perc')
plt.show()
