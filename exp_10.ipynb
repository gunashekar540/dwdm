# %% [markdown]
# <a href="https://colab.research.google.com/github/gunashekar540/dwdm/blob/main/exp_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
data=pd.read_csv('/content/hclustdata.csv')
data.head()
x=data[['SSC Perc\nentage','B.Tech perc']]

# %%
dbscan=DBSCAN(eps=5,min_samples=5)
dbscan.fit(x)
labels=dbscan.labels_
plt.scatter(x['SSC Perc\nentage'],x['B.Tech perc'],c=labels)
plt.show()
